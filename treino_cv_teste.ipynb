# %% [markdown]
# # House Sell Prices

# %% [markdown]
# Neste dataset, desejamos prever o preço de venda de casas no dataset de teste.

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 999)

# %% [markdown]
# Importar datasets de treino e teste

# %%
house_train = pd.read_csv('Regressão/HousePrices/train.csv', sep=',')
house_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
house_test = pd.read_csv('Regressão/HousePrices/test.csv', sep=',')
house_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
house_test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
house_train.shape, house_test.shape
# Out:
# ((1460, 81), (1459, 80))

# %% [markdown]
# Métricas de regressão

# %%
from sklearn import metrics

def calcMetricas(y, y_pred, verbose=False):
    metricas = {}
    metricas['mae'] = metrics.mean_absolute_error(y, y_pred)
    metricas['mse'] = metrics.mean_squared_error(y, y_pred)
    metricas['rmse'] = np.sqrt(metrics.mean_squared_error(y, y_pred))
    metricas['r2'] = metrics.r2_score(y, y_pred)
    
    if verbose:
        print('Mean Absolute Error:', metricas['mae'])
        print('Mean Squared Error:', metricas['mse'])
        print('Root Mean Squared Error:', metricas['rmse'])
        print('R2 score:', metricas['r2'])
    
    return metricas

# %% [markdown]
# ## DataPrep

# %% [markdown]
# Vamos utilizar somente as variaveis numéricas, a principio

# %%
numeric_fields = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold']
house_train = house_train[numeric_fields + ['SalePrice']].copy()
house_test = house_test[numeric_fields].copy()

# %% [markdown]
# Vamos fazer a substituição de NaN's por zeros

# %%
house_train.fillna(0, inplace=True)
house_test.fillna(0, inplace=True)

# %% [markdown]
# Vamos dividir o dataset de treino em treino e validação

# %%
X_train = house_train.drop(columns=['SalePrice'])
y_train = house_train['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %%
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((1022, 35), (438, 35), (1022,), (438,))

# %% [markdown]
# ## Cross Validation

# %% [markdown]
# Vamos utilizar K-Fold CV

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

kf = KFold(n_splits=5, shuffle=True, random_state=42)
metricas_treino = []
metricas_teste = []
count = 1
for train_index, test_index in kf.split(X_train):
    print("========== RODADA {} ==========".format(count))
    print("TRAIN:", len(train_index), "TEST:", len(test_index))
    
    X_cv_train, X_cv_test = X_train.iloc[train_index], X_train.iloc[test_index]
    y_cv_train, y_cv_test = y_train.iloc[train_index], y_train.iloc[test_index]
    
    print("# Fazendo fit do modelo")
    model = LinearRegression(normalize=True)
    model.fit(X_cv_train, y_cv_train)
    
    print("# Fazendo predições")
    y_cv_pred_train = model.predict(X_cv_train)
    y_cv_pred_test = model.predict(X_cv_test)
    
    print("# Calculando as métricas")
    print("## Treino")
    metricas_cv_treino = calcMetricas(y_cv_train, y_cv_pred_train, verbose=True)
    print("## Teste")
    metricas_cv_teste = calcMetricas(y_cv_test, y_cv_pred_test, verbose=True)
    print()
    
    metricas_treino.append(metricas_cv_treino)
    metricas_teste.append(metricas_cv_teste)
    
    count += 1

print("================ RESULTADO ================")
print("## Treino")
print("Média do MAE", np.mean(list(map(lambda x: x['mae'], metricas_treino))))
print("Média do MSE", np.mean(list(map(lambda x: x['mse'], metricas_treino))))
print("Média do RMSE", np.mean(list(map(lambda x: x['rmse'], metricas_treino))))
print("Média do R2", np.mean(list(map(lambda x: x['r2'], metricas_treino))))
print()
print("## Teste")
print("Média do MAE", np.mean(list(map(lambda x: x['mae'], metricas_teste))))
print("Média do MSE", np.mean(list(map(lambda x: x['mse'], metricas_teste))))
print("Média do RMSE", np.mean(list(map(lambda x: x['rmse'], metricas_teste))))
print("Média do R2", np.mean(list(map(lambda x: x['r2'], metricas_teste))))
# Out:
# ========== RODADA 1 ==========
# TRAIN: 817 TEST: 205
# # Fazendo fit do modelo
# # Fazendo predições
# # Calculando as métricas
# ## Treino
# Mean Absolute Error: 21898.290808618935
# Mean Squared Error: 1226297943.2577186
# Root Mean Squared Error: 35018.53713760354
# R2 score: 0.794425221346509
# ## Teste
# Mean Absolute Error: 21100.57990970648
# Mean Squared Error: 1063048250.1906326
# Root Mean Squared Error: 32604.420715458702
# R2 score: 0.8293374490441017
#
# ========== RODADA 2 ==========
# TRAIN: 817 TEST: 205
# # Fazendo fit do modelo
# # Fazendo predições
# # Calculando as métricas
# ## Treino
# Mean Absolute Error: 21718.007690765346
# Mean Squared Error: 1296517142.6377928
# Root Mean Squared Error: 36007.18182026737
# R2 score: 0.8027815501067388
# ## Teste
# Mean Absolute Error: 21723.678611453553
# Mean Squared Error: 836757909.0551188
# Root Mean Squared Error: 28926.768036804922
# R2 score: 0.775491410366535
#
# ========== RODADA 3 ==========
# ...

# %% [markdown]
# ## Treinando o modelo

# %% [markdown]
# Vamos utilizar um modelo simples de Regressão Linear

# %%
model = LinearRegression(normalize=True)
model.fit(X_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# ## Testando o resultado

# %% [markdown]
# Aplicamos train e validação no modelo treinado e vemos as métricas

# %%
y_pred_train = model.predict(X_train)
y_pred_valid = model.predict(X_valid)

print("# Calculando as métricas")
print("## Treino")
metricas_treino = calcMetricas(y_train, y_pred_train, verbose=True)
print("## Validação")
metricas_valid = calcMetricas(y_valid, y_pred_valid, verbose=True)
# Out:
# # Calculando as métricas
# ## Treino
# Mean Absolute Error: 21204.92458426887
# Mean Squared Error: 1182056192.42137
# Root Mean Squared Error: 34381.04408567852
# R2 score: 0.8035986756793865
# ## Validação
# Mean Absolute Error: 22763.191364332866
# Mean Squared Error: 1199777705.3015757
# Root Mean Squared Error: 34637.80745517209
# R2 score: 0.8280651211628208

# %% [markdown]
# Agora sim prevemos para o teste

# %%
X_test = house_test.copy()
y_pred_test = model.predict(X_test)

# %% [markdown]
# Exportamos o teste com a predição

# %%
X_test['SalePrice'] = y_pred_test.astype(np.int64)
X_test.to_csv('Regressão/HousePrices/test_predictions.csv')
